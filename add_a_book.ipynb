# %%
from theka import AddBook;

# %%
author = "Samuel Beckett"

title = "Waiting for Godot"

book_file = "./flow_of_books/book.txt"


with open(book_file, 'r') as file:
            book_content = file.read()
book = AddBook(author, title, book_content)
